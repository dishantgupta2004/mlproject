# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ucimlrepo import fetch_ucirepo

# %%
# fetch dataset 
energy_efficiency = fetch_ucirepo(id=242) 
# data (as pandas dataframes) 
column_X = ['Relative_Compactness', 'Surface_Area', 'Wall_Area', 'Roof_Area', 'Overall_Height', 'Orientation', 'Glazing_Area', 'Glazing_Area_Distribution']
column_Y = ['Heating_Load', 'Cooling_Load']
X = energy_efficiency.data.features 
y = energy_efficiency.data.targets 
df_X = pd.DataFrame(data= X)
df_y = pd.DataFrame(data= y )
df_X.columns = column_X
df_y.columns = column_Y

# %%
df_X
# Out:
#      Relative_Compactness  Surface_Area  Wall_Area  Roof_Area  Overall_Height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
# ...

# %%
df_X.info(), df_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Relative_Compactness       768 non-null    float64
#  1   Surface_Area               768 non-null    float64
#  2   Wall_Area                  768 non-null    float64
#  3   Roof_Area                  768 non-null    float64
#  4   Overall_Height             768 non-null    float64
#  5   Orientation                768 non-null    int64
#  6   Glazing_Area               768 non-null    float64
#  7   Glazing_Area_Distribution  768 non-null    int64
# dtypes: float64(6), int64(2)
# memory usage: 48.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Heating_Load  768 non-null    float64
# ...

# %%
for col in df_X.columns:
    print("Unique values in",col,"is: ", df_X[col].nunique())
    
for col in df_y.columns:
    print("Unique values in",col,"is ", df_y[col].nunique())
# Out:
# Unique values in Relative_Compactness is:  12
# Unique values in Surface_Area is:  12
# Unique values in Wall_Area is:  7
# Unique values in Roof_Area is:  4
# Unique values in Overall_Height is:  2
# Unique values in Orientation is:  4
# Unique values in Glazing_Area is:  4
# Unique values in Glazing_Area_Distribution is:  6
# Unique values in Heating_Load is  586
# Unique values in Cooling_Load is  636

# %%
for col in df_X.columns:
    print("Unique values in",col,"is: ", df_X[col].unique())
    
for col in df_y.columns:
    print("No of Unique values in",col,"is ", df_y[col].nunique())
# Out:
# Unique values in Relative_Compactness is:  [0.98 0.9  0.86 0.82 0.79 0.76 0.74 0.71 0.69 0.66 0.64 0.62]
# Unique values in Surface_Area is:  [514.5 563.5 588.  612.5 637.  661.5 686.  710.5 735.  759.5 784.  808.5]
# Unique values in Wall_Area is:  [294.  318.5 343.  416.5 245.  269.5 367.5]
# Unique values in Roof_Area is:  [110.25 122.5  147.   220.5 ]
# Unique values in Overall_Height is:  [7.  3.5]
# Unique values in Orientation is:  [2 3 4 5]
# Unique values in Glazing_Area is:  [0.   0.1  0.25 0.4 ]
# Unique values in Glazing_Area_Distribution is:  [0 1 2 3 4 5]
# No of Unique values in Heating_Load is  586
# No of Unique values in Cooling_Load is  636

# %%
for col in df_X.columns:
    plt.figure(figsize= (8, 6))
    sns.displot(df_X[col], kde= True)
    plt.xlabel(col)
    plt.ylabel("Target_variables")
    plt.legend()
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
df_X.describe()

## Almost constant values in above graphs  (more frequent common)
# Out:
#        Relative_Compactness  Surface_Area   Wall_Area   Roof_Area  \
# count            768.000000    768.000000  768.000000  768.000000
# mean               0.764167    671.708333  318.500000  176.604167
# std                0.105777     88.086116   43.626481   45.165950
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.682500    606.375000  294.000000  140.875000
# 50%                0.750000    673.750000  318.500000  183.750000
# 75%                0.830000    741.125000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        Overall_Height  Orientation  Glazing_Area  Glazing_Area_Distribution
# count       768.00000   768.000000    768.000000                  768.00000
# mean          5.25000     3.500000      0.234375                    2.81250
# std           1.75114     1.118763      0.133221                    1.55096
# ...

# %%
### Outlier detection
for col in df_X.columns:
    sns.boxplot(x= df_X[col], y= df_y["Cooling_Load"])
    plt.xlabel(col)
    plt.ylabel("Cooling Load")
    plt.show()

# %%
### Outlier detection
for col in df_X.columns:
    sns.boxplot(x= df_X[col], y= df_y["Heating_Load"])
    plt.xlabel(col)
    plt.ylabel("Heating Load")
    plt.show()

# %%
## No outliers only some insignificant outliers present that will does not impact our prediction
### Covariance checking

df_X.cov()
# Out:
#                            Relative_Compactness  Surface_Area    Wall_Area  \
# Relative_Compactness               1.118887e-02 -9.242069e+00    -0.940391
# Surface_Area                      -9.242069e+00  7.759164e+03   751.290743
# Wall_Area                         -9.403911e-01  7.512907e+02  1903.269883
# Roof_Area                         -4.150839e+00  3.503937e+03  -575.989570
# Overall_Height                     1.533246e-01 -1.323703e+02    21.465450
# Orientation                        0.000000e+00  0.000000e+00     0.000000
# Glazing_Area                      -2.894975e-19  1.871312e-15     0.000000
# Glazing_Area_Distribution          4.631960e-18  7.114691e-15     0.000000
#
#                               Roof_Area  Overall_Height   Orientation  \
# Relative_Compactness      -4.150839e+00        0.153325  0.000000e+00
# Surface_Area               3.503937e+03     -132.370274  0.000000e+00
# Wall_Area                 -5.759896e+02       21.465450  0.000000e+00
# ...

# %%
df_y.cov()
# Out:
#               Heating_Load  Cooling_Load
# Heating_Load    101.812050     93.674064
# Cooling_Load     93.674064     90.502983

# %%
sns.heatmap(df_X.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(df_y.corr(), annot=True, cmap='coolwarm')

## High correlation in between heating load and cooling load means as heating load increases by 1 unit then cooling load inc by 0.98 unit and vice versa
# Out:
# <Axes: >

# %%
### Variance Inflation Factor (for multicollinearity)

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = df_X.columns
vif_data["VIF"] = [variance_inflation_factor(df_X.values, i) for i in range(len(df_X.columns))]
# Out:
# c:\Users\disha\anaconda3\Lib\site-packages\statsmodels\stats\outliers_influence.py:198: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)

# %%
sns.pairplot(df_X)
plt.show()

# %%
## almost uniform and clean data
### so no need for data preprocessing
